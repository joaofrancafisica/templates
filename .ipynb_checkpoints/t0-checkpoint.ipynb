# %%
import glob #to read the files
import json #to work if .json
import numpy as np #to math
import pandas as pd #to save the data
import math #to convertion calculus
from astropy.time import Time #to time converting
from astropy import units #time correction
from astropy.coordinates import SkyCoord #time correction
from scipy import interpolate #to interpolate the wavelength and flux
from tabulate import tabulate #to export in table format
from scipy.interpolate import interp1d
#import scipy.optimize as opt
from scipy import optimize
from scipy import signal
import os.path
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel
from scipy import stats
import os.path 
import sncosmo

# %%
save_path = '/home/joao/Documentos/templates'

# %%
kernel = 10.0 * RBF(length_scale=10.0, length_scale_bounds=(5, 15)) + WhiteKernel(noise_level=1e-5, noise_level_bounds=(1e-10, 1e+1))

# %%
csp = sncosmo.get_magsystem('csp')
ab = sncosmo.get_magsystem('ab')
vega = sncosmo.get_magsystem('vega')

# %%
# %run ./functions.ipynb

# %%
hist = []
t0_values = []

# %%
#file = open("names.txt")
#lines = file.readlines()
#file.close()

# %%
#training_set = []

# %%
#for line in lines:
#    if line.startswith('#'): continue
#    co=line.rstrip().replace('INDEF','Nan').split()

#    training_set.append(co[0])

# %%
sn_names=glob.glob("*.json")

# %%
len(sn_names)
# Out:
# 378

# %%
maxvalues = []

# %%
#sn_names = ["SN2011fe.json"]

# %%
list_data = []
lightc = []

# %%
for j in range(0,len(sn_names)):  
    
    name = sn_names[j]

    print(name)
    
    with open(name, "r") as read_file:
        data = json.load(read_file)

    url = name
    if url.endswith('.json'):
        url = url[:-5]

    
    redshift = redshift_value(data[url])
    
    if redshift is not None:

        t0 = max_time(data[url])

        mag = []
        time = []
        system = []

        for i in range(0,len(data[url]["photometry"])):

            if "band" in data[url]["photometry"][i]:

                if data[url]["photometry"][i]["band"] == "V":

                    if "system" in data[url]["photometry"][i]:
                        
                        system.append(data[url]["photometry"][i]["system"])

                        mag.append(float(data[url]["photometry"][i]["magnitude"]))
                        time.append(float(data[url]["photometry"][i]["time"]))
                    
                    else:
                        
                        system.append("w")

                        mag.append(float(data[url]["photometry"][i]["magnitude"]))
                        time.append(float(data[url]["photometry"][i]["time"]))
        
        
        if len(time) > 3:
    
            maxvalues.append(min(mag))
            
            ntime = []
            nmag = []
            for i in range(0,len(mag)):

                if np.abs(time[i]- min(time)) < 100:
                        
                    if system[i] == "CSP":
                        
                        
                        nmag.append(csp.band_mag_to_flux(mag[i], 'cspv9844')*(1+redshift)**3)
                        ntime.append([time[i]])
                        
                    if system[i] == "AB":
                        #print("ab")
                        
                        nmag.append(ab.band_mag_to_flux(mag[i], 'cspv9844')*(1+redshift)**3)
                        ntime.append([time[i]])
                        
                    if system[i] == "Vega":
                        
                        #print("vega")
                        nmag.append(vega.band_mag_to_flux(mag[i], 'cspv9844')*(1+redshift)**3)
                        ntime.append([time[i]])   
                        
                    if system[i] == "w":
                        
                        #print("w")
                        nmag.append(vega.band_mag_to_flux(mag[i], 'cspv9844')*(1+redshift)**3)
                        ntime.append([time[i]])                     
                    
                  
                    #print(np.abs(time[i][0] - min(time[i])))
            
            #maxvalues.append(max(nmag))
                    
                
            if len(nmag) > 3:   
                
                gp = GaussianProcessRegressor(kernel=kernel, alpha=0.0).fit(ntime, nmag)

                X_ = np.linspace(min(ntime)[0], max(ntime)[0], 1000)

                y_mean, y_cov = gp.predict(X_[:, np.newaxis], return_cov=True)

                y_mean = list(y_mean)

                idx = y_mean.index(max(y_mean))

                if idx > 2: 
                    #if max(y_mean) < 0.5:
                    hist.append([X_[idx] - t0,sn_names[j]])
                    t0_values.append([X_[idx],sn_names[j]])

                    lightc.append([X_, y_mean])                    

                #list_data.append(max(y_mean))
                #list_data.append([X_, y_mean])
# Out:
# SN2006ax.json
# 0.016725
# SN2013bh.json
# 0.068
# SN2001el.json
# 0.00536
# SN2001ie.json
# 0.030738
# SN2007af.json
# 0.005464
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN2008hu.json
# 0.05056
# SN2000cx.json
# 0.007929
# SN1998dh.json
# 0.00897
# SN1980N.json
# 0.005871
# SN2012fr.json
# 0.0054
# vega
# ab
# ab
# vega
# ab
# vega
# ab
# vega
# ab
# ab
# vega
# ab
# vega
# ab
# vega
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# vega
# ab
# vega
# vega
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# vega
# ab
# vega
# vega
# ab
# ab
# vega
# ab
# vega
# ab
# vega
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# vega
# vega
# vega
# vega
# SN2003fd.json
# 0.060222
# SN2002ck.json
# 0.029864
# SN2003ae.json
# 0.0329
# SN2007A.json
# 0.017653315868428443
# SN2007fs.json
# 0.01719
# SN1995ak.json
# 0.02272
# SN2012dn.json
# 0.010187
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN2005al.json
# 0.012381930324267376
# SN2004bd.json
# 0.00893
# SN2008ar.json
# 0.026147
# SN2006D.json
# 0.008529
# PTF09dlc.json
# 0.0672
# SN2006gj.json
# 0.02829
# SN2013aa.json
# 0.003999
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# ab
# vega
# vega
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# vega
# ab
# ab
# ab
# SN2003M.json
# 0.02424
# SN2008hv.json
# 0.012526589416171241
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN1998aq.json
# 0.003699
# SN2001iq.json
# 0.01842
# SN2007kk.json
# 0.041045
# SN2000dg.json
# 0.03849
# SN2009dc.json
# 0.02158
# vega
# vega
# vega
# vega
# vega
# SN2001V.json
# 0.01502
# SN2005cf.json
# 0.006461
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN1999dk.json
# 0.01496
# SN1990R.json
# 0.0162
# SN2006le.json
# 0.017432
# SN2013ew.json
# 0.056
# SN2008s1.json
# 0.0221
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN2000E.json
# 0.00606
# SN1998bp.json
# 0.01043
# SN2005ej.json
# 0.037873
# SN2009D.json
# 0.025007
# SN2005hj.json
# 0.05802511117307718
# LSQ12fxd.json
# 0.031
# SN2004gc.json
# 0.030679357865528
# SN2003cq.json
# 0.033283
# SN1999gh.json
# 0.007679
# SN2006cj.json
# 0.067517
# SN2004S.json
# 0.00937
# SN1996by.json
# redshift nao encontrado
# SN2005bo.json
# 0.013870133763326464
# SN2006te.json
# 0.031592
# SN2005gj.json
# 0.0616
# SN2007N.json
# 0.012879
# SN2001br.json
# 0.020628
# SN2000ce.json
# 0.01631
# SN1999ej.json
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN2001ah.json
# 0.057756
# SN2003ek.json
# 0.036038
# SN2006ev.json
# 0.02873
# SN2007ax.json
# 0.006861
# SN2006fw.json
# 0.08302212937644482
# SN1989B.json
# 0.002425
# SN2006lf.json
# 0.013189
# SN2007fb.json
# 0.018026
# SN2002bo.json
# 0.00424
# SN1999ek.json
# 0.01752
# SN2007jg.json
# 0.03712646456081914
# SN2000dk.json
# 0.01744
# SN2008ae.json
# 0.03006
# vega
# vega
# vega
# vega
# vega
# vega
# SN2005hc.json
# 0.045948829040162176
# SN2001da.json
# 0.017195
# SN1956A.json
# 0.00559
# SN2006hb.json
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)" [astropy._erfa.core]
# 0.0153328042114802
# SN2001fe.json
# 0.013539
# SN2002ar.json
# 0.03009
# SN2002ha.json
# 0.014046
# SN2006gt.json
# 0.044771
# SN2002hw.json
# 0.017535
# SN2002cu.json
# 0.023323
# PTF10vqv.json
# redshift nao encontrado
# SN2002do.json
# 0.015881
# SN1998dm.json
# 0.006541
# LSQ12ege.json
# 0.08
# SN2005ki.json
# 0.019207
# SN2001ck.json
# 0.034721
# SN2007au.json
# 0.020584
# SN2006N.json
# 0.014277
# SN1993Z.json
# 0.00452
# SN2002cx.json
# 0.02396
# SN2001E.json
# 0.01926
# SN2008Z.json
# 0.02099
# SN2007bc.json
# 0.02077
# SN2008gl.json
# 0.034017
# SN2013hn.json
# 0.01514
# vega
# SN2004bv.json
# 0.01061
# SN2001G.json
# 0.01677
# SN1991K.json
# 0.017
# SN2008ec.json
# 0.016317
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# SN2003kd.json
# 0.0302
# SN2008dr.json
# 0.041449
# SN2013cs.json
# 0.009
# ab
# ab
# vega
# vega
# vega
# ab
# vega
# vega
# vega
# ab
# vega
# vega
# ab
# vega
# ab
# ab
# ab
# vega
# ab
# vega
# ab
# ab
# vega
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# ab
# SN2010jn.json
# 0.025047
# vega
# vega
# vega
# vega
# vega
# vega
# PTF10ops.json
# 0.06
# SN2007bj.json
# 0.016708
# SN2002dj.json
# 0.009393
# SN1954B.json
# 0.00609
# SN2006mr.json
# 0.00586826659018258
# WARNING: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)" [astropy._erfa.core]
# SN1998dx.json
# 0.054221
# SN2009ab.json
# 0.01117
# SN2007ap.json
# 0.015818
# SN2007al.json
# 0.012122
# SN1990M.json
# 0.00904
# SN2002er.json
# 0.008569
# SN1990U.json
# 0.007935
# SN2002hd.json
# 0.035001
# SN2001az.json
# 0.040701
# LSQ12fhs.json
# 0.033145
# SN1999aa.json
# 0.01444
# SN2013gh.json
# 0.0088
# vega
# vega
# vega
# vega
# vega
# vega
# vega
# vega

# %%
#list_data_temp = []

# %%
'''
for i in range(0,len(maxvalues)):
    
    if maxvalues[i]<25:
        
        list_data_temp.append(maxvalues[i])
'''
# Out:
# '\nfor i in range(0,len(maxvalues)):\n    \n    if maxvalues[i]<25:\n        \n        list_data_temp.append(maxvalues[i])\n'

# %%
system
# Out:
# ['Vega', 'Vega', 'Vega', 'Vega', 'Vega', 'Vega', 'Vega', 'Vega']

# %%
# %matplotlib inline
plt.hist(maxvalues, bins=30)
#plt.xlim(0,30)
plt.show()

# %%
len(lightc)
# Out:
# 84

# %%
# %matplotlib inline
for i in range(0,len(lightc)):
    
    plt.plot(lightc[i][0],lightc[i][1])
    
plt.show()

# %%
hist_1 = []
for i in range(0,len(hist)):
    
    if np.abs(hist[i][0]) < 20:
        
        hist_1.append([hist[i][0], hist[i][1]])

# %%
hist_val = []

# %%
for i in range(0,len(hist_1)):
    
    hist_val.append(hist_1[i][0])

# %%
# %matplotlib notebook

plt.hist(hist_val, bins=30)
plt.ylabel('Probability')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
hist_1
# Out:
# [[4.067827687686076, 'SN2006ax.json'],
#  [3.2333376376336673, 'SN2007af.json'],
#  [3.799608608605922, 'SN2012fr.json'],
#  [5.257336216214753, 'SN2007A.json'],
#  [4.783177377379616, 'SN2012dn.json'],
#  [0.824668308305263, 'SN2005al.json'],
#  [0.6537577777780825, 'SN2006D.json'],
#  [-19.450993123122316, 'SN2006gj.json'],
#  [4.89505555555661, 'SN2013aa.json'],
#  [3.7204360360337887, 'SN2008hv.json'],
#  [0.4738612612563884, 'SN2009dc.json'],
#  [2.425065965966496, 'SN2005cf.json'],
#  [4.445165065066249, 'SN2008s1.json'],
#  [-1.5019273273283034, 'SN2005hj.json'],
#  [1.433473233228142, 'SN2005bo.json'],
#  [-3.6193317417419166, 'SN2007N.json'],
#  [2.7902818618604215, 'SN2007ai.json'],
#  [2.2900781981952605, 'SN2005bl.json'],
#  [0.9414468468457926, 'SN2007cq.json'],
#  [2.861431531528069, 'SN2012hr.json'],
#  [5.518982582587341, 'SN2009jb.json'],
#  [-2.02379909910087, 'SN2009Y.json'],
#  [3.4974821521536796, 'SN2007bm.json'],
#  [5.996829929928936, 'SN2015bp.json'],
#  [1.1145715615639347, 'SN2007le.json'],
#  [-3.7846907807761454, 'SN2006ob.json'],
#  [5.3916765965987, 'SN2006kf.json'],
#  [2.0775571471531293, 'SN2005na.json'],
#  [0.37520873874018434, 'SN2007bd.json'],
#  [-5.610823153154342, 'SN2005A.json'],
#  [-4.176400740740064, 'SN2005ke.json'],
#  [5.753423723726883, 'SN2006ej.json'],
#  [-11.99576333333971, 'SN2007ca.json'],
#  [2.2331502402448677, 'SN2004ey.json'],
#  [-0.845490690691804, 'SN2008R.json'],
#  [4.438693793788843, 'SN2011ay.json'],
#  [6.275419019017136, 'SN2010gn.json'],
#  [1.6618750750785694, 'SN2006dm.json'],
#  [4.647447447445302, 'SN2014J.json'],
#  [-1.106840090091282, 'SN2007ba.json'],
#  [4.481510900899593, 'SN2006bt.json'],
#  [1.512735605603666, 'SN2004ef.json'],
#  [5.219324324323679, 'SN2012ht.json'],
#  [4.9356671671703225, 'SN2008Q.json'],
#  [2.058142252251855, 'SN2005am.json'],
#  [6.547747747747053, 'LSQ12gdj.json'],
#  [3.018111411409336, 'SN2012cg.json'],
#  [5.591580480482662, 'SN2014at.json'],
#  [12.701886486487638, 'SN2007co.json'],
#  [6.245818628623965, 'SN2005kc.json'],
#  [3.661976576579036, 'SN2010ae.json'],
#  [-1.048640610606526, 'SN2007nq.json'],
#  [3.7440520420423127, 'SN2005ag.json'],
#  [7.721019349351991, 'SN2008ia.json'],
#  [4.714548468466091, 'SN2008fp.json'],
#  [-2.2166612612563767, 'SN2008A.json'],
#  [-2.3182054554563365, 'SN2009F.json'],
#  [4.562494594596501, 'SN2005hk.json'],
#  [7.266765675674833, 'SN2007S.json'],
#  [5.987266156160331, 'SN2005eq.json'],
#  [4.707836236237199, 'iPTF13dge.json'],
#  [-0.41633762762648985, 'SN2008bc.json'],
#  [6.163708408406819, 'SN2011fe.json'],
#  [1.365946946949407, 'SN2009ig.json'],
#  [0.7346642142147175, 'SN2005M.json'],
#  [7.453827447454387, 'SN2005el.json'],
#  [3.6914189189192257, 'iPTF14bdn.json'],
#  [1.0126991691649891, 'SN2006et.json'],
#  [1.968207777776115, 'SN2004eo.json'],
#  [3.5621724724696833, 'SN2006X.json'],
#  [5.403530750751088, 'SN2007on.json'],
#  [3.501667537537287, 'SN2007ax.json'],
#  [5.4958706306279055, 'SN2006fw.json'],
#  [0.8921118518555886, 'SN2007jg.json'],
#  [-10.671532832828234, 'SN2008ae.json'],
#  [1.423788778782182, 'SN2005hc.json'],
#  [9.664303513513005, 'SN2006gt.json'],
#  [2.149658378380991, 'SN2005ki.json'],
#  [-1.2142763063093298, 'SN2007bc.json'],
#  [0.4679972972953692, 'SN2008ec.json'],
#  [0.596647647646023, 'SN2013cs.json'],
#  [4.619094694695377, 'SN2010jn.json'],
#  [-0.9190549049089896, 'SN2006mr.json'],
#  [1.8253918918926502, 'SN2013gh.json']]

# %%
len(hist_1)
# Out:
# 84

# %%
names = []
zerotime = []

# %%
for i in range(0,len(t0_values)):
    
    zerotime.append(t0_values[i][0])
    names.append(t0_values[i][1][:-5])

# %%
names
# Out:
# ['SN2006ax',
#  'SN2007af',
#  'SN2012fr',
#  'SN2007A',
#  'SN2012dn',
#  'SN2005al',
#  'SN2006D',
#  'SN2006gj',
#  'SN2013aa',
#  'SN2008hv',
#  'SN2009dc',
#  'SN2005cf',
#  'SN2008s1',
#  'SN2005hj',
#  'SN2005bo',
#  'SN2007N',
#  'SN2007ai',
#  'SN2005bl',
#  'SN2007cq',
#  'SN2012hr',
#  'SN2009jb',
#  'SN2009Y',
#  'SN2007bm',
#  'SN2015bp',
#  'SN2007le',
#  'SN2006ob',
#  'SN2006kf',
#  'SN2005na',
#  'SN2007bd',
#  'SN2005A',
#  'SN2005ke',
#  'SN2006ej',
#  'SN2007ca',
#  'SN2004ey',
#  'SN2008R',
#  'SN2011ay',
#  'SN2010gn',
#  'SN2006dm',
#  'SN2014J',
#  'SN2007ba',
#  'SN2006bt',
#  'SN2004ef',
#  'SN2012ht',
#  'SN2008Q',
#  'SN2005am',
#  'LSQ12gdj',
#  'SN2012cg',
#  'SN2014at',
#  'SN2007co',
#  'SN2005kc',
#  'SN2010ae',
#  'SN2007nq',
#  'SN2005ag',
#  'SN2008ia',
#  'SN2008fp',
#  'SN2008A',
#  'SN2009F',
#  'SN2005hk',
#  'SN2007S',
#  'SN2005eq',
#  'iPTF13dge',
#  'SN2008bc',
#  'SN2011fe',
#  'SN2009ig',
#  'SN2005M',
#  'SN2005el',
#  'iPTF14bdn',
#  'SN2006et',
#  'SN2004eo',
#  'SN2006X',
#  'SN2007on',
#  'SN2007ax',
#  'SN2006fw',
#  'SN2007jg',
#  'SN2008ae',
#  'SN2005hc',
#  'SN2006gt',
#  'SN2005ki',
#  'SN2007bc',
#  'SN2008ec',
#  'SN2013cs',
#  'SN2010jn',
#  'SN2006mr',
#  'SN2013gh']

# %%
'''
table = []
for l in range(0,len(names)):
    table.append((names[l],zerotime[l]))

name_of_file = "t0_values"

completeName = os.path.join(save_path, name_of_file+".txt")

f = open(completeName, 'w')
f.write(tabulate(table, tablefmt="plain"))
f.close()
'''
# Out:
# '\ntable = []\nfor l in range(0,len(names)):\n    table.append((names[l],zerotime[l]))\n\nname_of_file = "t0_values"\n\ncompleteName = os.path.join(save_path, name_of_file+".txt")\n\nf = open(completeName, \'w\')\nf.write(tabulate(table, tablefmt="plain"))\nf.close()\n'

# %%
# %matplotlib notebook
plt.plot(time,mag,'.')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">
# <img src="data:image/png;base64,..." width="432">

# %%
table = []
for l in range(0,len(names)):
    table.append((names[l],maxvalues[l]))

name_of_file = "max_valuesV"

completeName = os.path.join(save_path, name_of_file+".txt")

f = open(completeName, 'w')
f.write(tabulate(table, tablefmt="plain"))
f.close()

# %%
maxvalues
# Out:
# [15.205,
#  13.21,
#  11.91,
#  15.726,
#  14.27,
#  15.076,
#  14.207,
#  17.628,
#  11.616,
#  14.822,
#  15.27,
#  13.552,
#  16.149,
#  17.764,
#  16.629,
#  17.354,
#  15.551,
#  17.27,
#  17.806,
#  17.883,
#  16.097,
#  13.75,
#  15.942,
#  14.141,
#  14.149,
#  13.784,
#  13.698,
#  18.247,
#  17.884,
#  16.573,
#  16.624,
#  16.256,
#  16.636,
#  17.301,
#  14.142,
#  15.821,
#  15.847,
#  15.211,
#  15.383,
#  16.728,
#  16.889,
#  16.096,
#  16.295,
#  10.584,
#  17.597,
#  16.94,
#  16.912,
#  13.067,
#  13.703,
#  15.877,
#  13.765,
#  15.95,
#  12.791,
#  11.904,
#  16.502,
#  17.537,
#  16.678,
#  15.754,
#  15.576,
#  17.177,
#  17.104,
#  17.463,
#  18.48,
#  16.502,
#  13.962,
#  16.118,
#  16.663,
#  15.681,
#  17.349,
#  15.494,
#  16.463,
#  15.357,
#  15.489,
#  9.971,
#  13.422,
#  15.991,
#  15.277,
#  18.388,
#  14.841,
#  20.242,
#  15.878,
#  17.581,
#  15.362,
#  13.974,
#  12.96,
#  17.299,
#  15.703,
#  18.915,
#  17.511,
#  17.937,
#  17.394,
#  15.946,
#  18.11,
#  15.682,
#  15.927,
#  15.245,
#  15.593,
#  13.829,
#  16.833,
#  14.624,
#  14.231]

# %%
mag
# Out:
# [14.93, 14.715, 14.529, 14.231, 14.295, 14.235, 14.232, 14.346]
