# %%
import scipy as sp
import scipy.interpolate
import numpy as np
import scipy.interpolate as interp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

file = open("salt2_template_0.dat")
lines = file.readlines()
file.close()
    
xtemp = []
ytemp = []
ztemp = []
    
for line in lines:
    
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    xtemp.append(co[0])
    ytemp.append(co[1])
    ztemp.append(co[2])

xtemp = np.array(xtemp, dtype=float)
ytemp = np.array(ytemp, dtype=float)
ztemp = np.array(ztemp, dtype=float)
    
gradex,gradey = np.meshgrid(np.linspace(-20,50,70),np.linspace(2000,9200,50))

f = interp.griddata((xtemp,ytemp),ztemp,(gradex,gradey),method='linear')

# %matplotlib notebook
fig = plt.figure(figsize=(10,6))
ax = axes3d.Axes3D(fig)
ax.set_ylim([2000,9200])
ax.set_xlim([-20,50])
ax.plot_wireframe(gradex, gradey, f)
ax.plot_surface(gradex, gradey, f,alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
file = open("M0.dat")
lines = file.readlines()
file.close()
    
xsub = []
ysub = []
zsub = []
    
for line in lines:
    
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    xsub.append(co[0])
    ysub.append(co[1])
    zsub.append(co[2])

xsub = np.array(xsub, dtype=float)
ysub = np.array(ysub, dtype=float)
zsub = np.array(zsub, dtype=float)

gradex,gradey = np.meshgrid(np.linspace(min(xsub),max(xsub),100),np.linspace(min(ysub),max(ysub),100))

fsub = interp.griddata((xsub,ysub),zsub,(gradex,gradey),method='linear')

# %matplotlib notebook
fig = plt.figure(figsize=(10,6))
ax = axes3d.Axes3D(fig)
ax.set_ylim([2000,9200])
ax.set_xlim([-20,50])
ax.plot_wireframe(gradex, gradey, fsub)
ax.plot_surface(gradex, gradey, fsub,alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
from matplotlib import pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure()
ax = Axes3D(fig)
plt.xlabel('time (days)')
plt.ylabel('wavelength ($\AA$)')

def init():
    # Plot the surface.
    ax.plot_surface(gradex, gradey, f, cmap=cm.coolwarm,
                       linewidth=0, antialiased=True)
    return fig,

def animate(i):
    # azimuth angle : 0 deg to 360 deg
    ax.view_init(elev=10, azim=i*4)
    return fig,

ani = animation.FuncAnimation(fig, animate, init_func=init, frames=90, interval=50, blit=True)

fn = 'M0salt'

ani.save(fn+'.gif',writer='imagemagick',fps=1000/50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# MovieWriter stderr:
# magick.exe: unexpected end-of-file '-': No such file or directory @ error/rgb.c/ReadRGBImage/245.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1138                     # Clear the initial frame
# -> 1139                     anim._init_draw()
#    1140                 frame_number = 0
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1734         else:
# -> 1735             self._drawn_artists = self._init_func()
#    1736             if self._blit:
#
# <ipython-input-5-08b11094f5b8> in init()
#      13     ax.plot_surface(gradex, gradey, f, cmap=cm.coolwarm,
# ---> 14                        linewidth=0, antialiased=True)
#      15     return fig,
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1620         # TODO: Support masked arrays
# -> 1621         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#    1622         rows, cols = Z.shape
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-5-08b11094f5b8> in <module>
#      24 fn = 'M0salt'
#      25
# ---> 26 ani.save(fn+'.gif',writer='imagemagick',fps=1000/50)
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in finish(self)
#     365     def finish(self):
#     366         '''Finish any processing for writing the movie.'''
# --> 367         self.cleanup()
#     368
#     369     def grab_frame(self, **savefig_kwargs):
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in cleanup(self)
#     409         if self._proc.returncode:
#     410             raise subprocess.CalledProcessError(
# --> 411                 self._proc.returncode, self._proc.args, out, err)
#     412
#     413     @classmethod
#
# CalledProcessError: Command '['C:\\Program Files\\ImageMagick-7.0.8-Q16\\magick.exe', '-size', '640x480', '-depth', '8', '-delay', '5.0', '-loop', '0', 'rgba:-', 'M0salt.gif']' returned non-zero exit status 1.

# %%
fig = plt.figure()
ax = Axes3D(fig)
plt.xlabel('time (days)')
plt.ylabel('wavelength ($\AA$)')

def init():
    # Plot the surface.
    ax.plot_surface(gradex, gradey, fsub, cmap=cm.coolwarm,
                       linewidth=0, antialiased=True)
    return fig,

def animate(i):
    # azimuth angle : 0 deg to 360 deg
    ax.view_init(elev=10, azim=i*4)
    return fig,

ani = animation.FuncAnimation(fig, animate, init_func=init, frames=90, interval=50, blit=True)

fn = 'M0salt'

ani.save(fn+'.gif',writer='imagemagick',fps=1000/50)
# Out:
# <img src="data:image/png;base64,..." width="640">
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   if __name__ == '__main__':
# MovieWriter stderr:
# magick.exe: unexpected end-of-file '-': No such file or directory @ error/rgb.c/ReadRGBImage/245.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1138                     # Clear the initial frame
# -> 1139                     anim._init_draw()
#    1140                 frame_number = 0
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in _init_draw(self)
#    1734         else:
# -> 1735             self._drawn_artists = self._init_func()
#    1736             if self._blit:
#
# <ipython-input-12-ab632a62c58e> in init()
#       8     ax.plot_surface(gradex, gradey, fsub, cmap=cm.coolwarm,
# ----> 9                        linewidth=0, antialiased=True)
#      10     return fig,
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1620         # TODO: Support masked arrays
# -> 1621         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#    1622         rows, cols = Z.shape
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(*args, **kwargs)
#     258
# --> 259     shape = _broadcast_shape(*args)
#     260
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     192     # consistently
# --> 193     b = np.broadcast(*args[:32])
#     194     # unfortunately, it cannot handle 32 or more arguments directly
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-12-ab632a62c58e> in <module>
#      19 fn = 'M1salt'
#      20
# ---> 21 ani.save(fn+'.gif',writer='imagemagick',fps=1000/50)
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1154                             progress_callback(frame_number, total_frames)
#    1155                             frame_number += 1
# -> 1156                     writer.grab_frame(**savefig_kwargs)
#    1157
#    1158         # Reconnect signal for first draw if necessary
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in finish(self)
#     365     def finish(self):
#     366         '''Finish any processing for writing the movie.'''
# --> 367         self.cleanup()
#     368
#     369     def grab_frame(self, **savefig_kwargs):
#
# c:\users\usuario\appdata\local\programs\python\python37\lib\site-packages\matplotlib\animation.py in cleanup(self)
#     409         if self._proc.returncode:
#     410             raise subprocess.CalledProcessError(
# --> 411                 self._proc.returncode, self._proc.args, out, err)
#     412
#     413     @classmethod
#
# CalledProcessError: Command '['C:\\Program Files\\ImageMagick-7.0.8-Q16\\magick.exe', '-size', '640x480', '-depth', '8', '-delay', '5.0', '-loop', '0', 'rgba:-', 'M1salt.gif']' returned non-zero exit status 1.
