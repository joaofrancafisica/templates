# %%
import glob #to read the data files
import numpy as np #to math 
import math #to math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 
import ipywidgets as widgets
from IPython.display import display
# %matplotlib nbagg

# %%
file = open("training_names.txt")
lines = file.readlines()
file.close()

sn_names = []

for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()
    sn_names.append(co[0])

# %%
sn_names
# Out:
# ['SN2012fr.json',
#  'SN2011fe.json',
#  'SN2008ar.json',
#  'SN2007sr.json',
#  'SN2007af.json',
#  'SN2005cf.json',
#  'LSQ12gdj.json']

# %%
names = []
for u in range(0,len(sn_names)):
    url=sn_names[u]
    if url.endswith('.json'):
        url = url[:-5]
        names.append(url+'.dat')

# %%
names
# Out:
# ['SN2012fr.dat',
#  'SN2011fe.dat',
#  'SN2008ar.dat',
#  'SN2007sr.dat',
#  'SN2007af.dat',
#  'SN2005cf.dat',
#  'LSQ12gdj.dat']

# %%
#names=glob.glob("*.dat")
# %matplotlib notebook
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

plt.suptitle("supernova")
    
def update_graph(i):

    ax.clear()
    
    #oppening the files
    file = open(names[i])
    lines = file.readlines()
    file.close()

    #temporary lists
    xe=[]
    ye=[]
    ze=[]

    #to separate the collumns
    for line in lines:
        if line.startswith('#'): continue
        co=line.rstrip().replace('INDEF','Nan').split()

        #saving in temporary lists
        xe.append(co[0])
        ye.append(co[1])
        ze.append(co[2])

    #to float
    xe = np.array(xe, dtype=float)
    ye = np.array(ye, dtype=float)
    ze = np.array(ze, dtype=float)


    ax.scatter(xe, ye, ze)
    print(names[i])
    ax.set_xlim3d(-20,50)
    ax.set_ylim3d(2000,9200)
    plt.show()
    
i = widgets.IntSlider(min= 0, max = len(names)-1, value = 0, description = 'supernova:')
widgets.interactive(update_graph,i = i)
# Out:
# ...
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='supernova:', max=6), Output()), _dom_classes=('widget-in…

# %%
print(names)
# Out:
# ['SN2005cf.dat', 'SN2008ar.dat', 'SN2007af.dat', 'SN2012fr.dat', 'LSQ12gdj.dat', 'SN2011fe.dat']
